# %% [markdown]
# <a href="https://colab.research.google.com/github/SikanderBinMukaram/Object-Detection-Tracking-Yolo-DeepSort/blob/main/Bird_detection%2Ctracking%26recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Please turn on the gpu from runtime -> change runtime type -> gpu

# %%
#clone the github repository
# !git clone https://github.com/theAIGuysCode/yolov4-deepsort.git
# Out:
# Cloning into 'yolov4-deepsort'...
# remote: Enumerating objects: 143, done.
# remote: Total 143 (delta 0), reused 0 (delta 0), pack-reused 143
# Receiving objects: 100% (143/143), 76.84 MiB | 43.96 MiB/s, done.
# Resolving deltas: 100% (41/41), done.

# %%
#install the requirements for gpu
# !pip install -r yolov4-deepsort/requirements-gpu.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached tensorflow_gpu-2.11.0rc1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (588.4 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 kB 27.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 60.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 105.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 95.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 53.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.12.0
#     Uninstalling tensorflow-estimator-2.12.0:
#       Successfully uninstalled tensorflow-estimator-2.12.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.0
# ...

# %%
#download pre-trained weights for yolo4
# %cd yolov4-deepsort/data/
import gdown #for downloading pretrained weights

# !gdown https://drive.google.com/u/0/uc?id=1cewMfusmPjYWbrnuJRuKhPMwRe_b9PaT&export=download
# Out:
# /content/yolov4-deepsort/data
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1cewMfusmPjYWbrnuJRuKhPMwRe_b9PaT
# To: /content/yolov4-deepsort/data/yolov4.weights
# 258MB [00:02, 102MB/s]

# %%
#go back to parent directory
# %cd ..
# Out:
# /content/yolov4-deepsort

# %%
#convert the weights into a tensorflow model

# !python save_model.py --model yolov4

# %%
# Download the video 
# %cd data/video/
# !gdown https://drive.google.com/u/0/uc?id=1QQpHTK8w05ZVbXjWYc8UOPlYDN52RSVO&export=download
# Out:
# /content/yolov4-deepsort/data/video
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1QQpHTK8w05ZVbXjWYc8UOPlYDN52RSVO
# To: /content/yolov4-deepsort/data/video/pexels-creativ-medium-5747327.mp4
# 66.0MB [00:00, 86.3MB/s]

# %%
#back to parent directory
# !pwd
# %cd ./../..
# Out:
# /content/yolov4-deepsort/data/video
# /content/yolov4-deepsort

# %%
#test on our video
#upload the bird tracker file
# !gdown https://drive.google.com/u/0/uc?id=1TD1-rDtzeLuABLaHds9z-3xGK2O32CxK&export=download
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1TD1-rDtzeLuABLaHds9z-3xGK2O32CxK
# To: /content/yolov4-deepsort/bird_tracker.py
# 100% 11.6k/11.6k [00:00<00:00, 22.7MB/s]

# %%
# !python bird_tracker.py --video ./data/video/pexels-creativ-medium-5747327.mp4 --output ./outputs/Birds.avi --model yolov4 --dont_show True
# Out:
# Frame #:  1
# FPS: 0.35
# Frame #:  2
# FPS: 9.98
# Frame #:  3
# FPS: 9.89
# Frame #:  4
# FPS: 9.49
# Frame #:  5
# FPS: 10.23
# Frame #:  6
# FPS: 9.99
# Frame #:  7
# FPS: 9.29
# Frame #:  8
# FPS: 9.09
# Frame #:  9
# FPS: 10.13
# Frame #:  10
# FPS: 10.23
# Frame #:  11
# FPS: 10.32
# Frame #:  12
# FPS: 9.31
# Frame #:  13
# FPS: 9.82
# Frame #:  14
# FPS: 9.94
# Frame #:  15
# FPS: 9.03
# Frame #:  16
# FPS: 9.33
# Frame #:  17
# FPS: 10.37
# Frame #:  18
# FPS: 10.37
# Frame #:  19
# FPS: 9.68
# Frame #:  20
# FPS: 9.01
# Frame #:  21
# FPS: 10.08
# Frame #:  22
# FPS: 9.98
# Frame #:  23
# FPS: 9.17
# Frame #:  24
# FPS: 9.38
# Frame #:  25
# FPS: 10.10
# Frame #:  26
# FPS: 10.20
# Frame #:  27
# FPS: 9.28
# Frame #:  28
# FPS: 9.14
# Frame #:  29
# FPS: 10.04
# Frame #:  30
# FPS: 9.38
# Frame #:  31
# FPS: 9.50
# Frame #:  32
# FPS: 9.47
# Frame #:  33
# FPS: 9.40
# Frame #:  34
# FPS: 10.10
# Frame #:  35
# FPS: 9.25
# Frame #:  36
# FPS: 9.23
# Frame #:  37
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
